# %%
# Enable Intellisense
# %config IPCompleter.greedy=True

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Dependencies and Setup
import pandas as pd

# File to Load
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
df = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
# check data types
df.dtypes
# Out:
# Student ID        int64
# student_name     object
# gender           object
# grade            object
# school_name      object
# reading_score     int64
# math_score        int64
# School ID         int64
# type             object
# size              int64
# budget            int64
# dtype: object

# %%
# find total number of unique school names and confirm
total_schools = df["school_name"].nunique()
print(total_schools)
print(df["school_name"].unique())
# Out:
# 15
# ['Huang High School' 'Figueroa High School' 'Shelton High School'
#  'Hernandez High School' 'Griffin High School' 'Wilson High School'
#  'Cabrera High School' 'Bailey High School' 'Holden High School'
#  'Pena High School' 'Wright High School' 'Rodriguez High School'
#  'Johnson High School' 'Ford High School' 'Thomas High School']

# %%
# find total number of students in district
total_students = df["student_name"].count()

total_students
# Out:
# 39170

# %%
# find unique school budgets
unique_budget = df["budget"].unique()

unique_budget
# Out:
# array([1910635, 1884411, 1056600, 3022020,  917500, 1319574, 1081356,
#        3124928,  248087,  585858, 1049400, 2547363, 3094650, 1763916,
#        1043130], dtype=int64)

# %%
# compute total budget of all schools
total_budget = sum(unique_budget)

total_budget
# Out:
# 24649428

# %%
# calculate average math score
math_average = df["math_score"].mean()
math_average
# Out:
# 78.98537145774827

# %%
# calculate average math score
reading_average = df["reading_score"].mean()
reading_average
# Out:
# 81.87784018381414

# %%
# count the number of students passing math
pass_math_count = (df["math_score"]>=70).sum()

pass_math_count
# Out:
# 29370

# %%
pct_pass_math = pass_math_count/total_students * 100

pct_pass_math
# Out:
# 74.9808526933878

# %%
# count the number of students passing reading
pass_reading_count = (df["reading_score"]>=70).sum()

pass_reading_count
# Out:
# 33610

# %%
pct_pass_reading = pass_reading_count/total_students * 100

pct_pass_reading
# Out:
# 85.80546336482001

# %%
# count the number of students passing math and reading
pass_overall_count = len(df[(df["math_score"]>=70) & (df["reading_score"]>=70)])

pass_overall_count
# Out:
# 25528

# %%
pct_pass_overall = pass_overall_count/total_students * 100

pct_pass_overall
# Out:
# 65.17232575950983

# %%
# place all of the data into a new district summary DataFrame and display
district_summary_df = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget.astype(float)],
    "Average Math Score": [math_average],
    "Average Reading Score": [reading_average],
    "% Passing Math": [pct_pass_math],
    "% Passing Reading": [pct_pass_reading],
    "% Overall Passing": [pct_pass_overall]
})

district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170    24649428.0           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# format data in table to match homework example
district_summary_df['Total Students'] = district_summary_df['Total Students'].map("{:,.0f}".format)
district_summary_df['Total Budget'] = district_summary_df['Total Budget'].map("${:,.2f}".format)

district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# display data in easier to read format
district_summary_df.style.hide_index()
district_summary_df['Average Math Score'] = district_summary_df['Average Math Score'].map("{:,.2f}".format)
district_summary_df['Average Reading Score'] = district_summary_df['Average Reading Score'].map("{:,.2f}".format)
district_summary_df['% Passing Math'] = district_summary_df['% Passing Math'].map("{:.2f}".format)
district_summary_df['% Passing Reading'] = district_summary_df['% Passing Reading'].map("{:.2f}".format)
district_summary_df['% Overall Passing'] = district_summary_df['% Overall Passing'].map("{:.2f}".format)

district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00              78.99
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.88          74.98             85.81             65.17

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# create variable for GroupBy school name
school = df.set_index('school_name').groupby(['school_name'])

# %%
school_name = df['school_name']

school_name.head(3)
# Out:
# 0    Huang High School
# 1    Huang High School
# 2    Huang High School
# Name: school_name, dtype: object

# %%
# determine school type
school_type = df.set_index('school_name')['type']

school_type.head(3)
# Out:
# school_name
# Huang High School    District
# Huang High School    District
# Huang High School    District
# Name: type, dtype: object

# %%
# determine number of students in school
school_pop = school["student_name"].count()

school_pop.head(3)
# Out:
# school_name
# Bailey High School      4976
# Cabrera High School     1858
# Figueroa High School    2949
# Name: student_name, dtype: int64

# %%
# determine budget for each school
school_budget = df.set_index('school_name')['budget']

school_budget.head(3)
# Out:
# school_name
# Huang High School    1910635
# Huang High School    1910635
# Huang High School    1910635
# Name: budget, dtype: int64

# %%
# calculate per student budget per school
student_budget = school_budget/school_pop

student_budget.head(3)
# Out:
# school_name
# Bailey High School    628.0
# Bailey High School    628.0
# Bailey High School    628.0
# dtype: float64

# %%
# calculate average math score per school
avg_math_school = school['math_score'].mean()

avg_math_school.head(3)
# Out:
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Name: math_score, dtype: float64

# %%
# calculate average reading score per school
avg_read_school = school['reading_score'].mean()

avg_read_school.head(3)
# Out:
# school_name
# Bailey High School      81.033963
# Cabrera High School     83.975780
# Figueroa High School    81.158020
# Name: reading_score, dtype: float64

# %%
# calculate percent passing math per school
pass_math_school = df.loc[df['math_score'] >= 70].groupby('school_name')['student_name'].count() / school_pop * 100

pass_math_school.head(3)
# Out:
# school_name
# Bailey High School      66.680064
# Cabrera High School     94.133477
# Figueroa High School    65.988471
# Name: student_name, dtype: float64

# %%
# calculate percent passing reading per school
pass_reading_school = df.loc[df["reading_score"] >= 70].groupby('school_name')['student_name'].count() / school_pop * 100


pass_reading_school.head(3)
# Out:
# school_name
# Bailey High School      81.933280
# Cabrera High School     97.039828
# Figueroa High School    80.739234
# Name: student_name, dtype: float64

# %%
# calculate overall percent passing per school
pass_overall_school = df.loc[(df['math_score'] >= 70) & (df['reading_score'] >= 70)].groupby('school_name')['student_name'].count() / school_pop * 100

pass_overall_school.head(3)
# Out:
# school_name
# Bailey High School      54.642283
# Cabrera High School     91.334769
# Figueroa High School    53.204476
# Name: student_name, dtype: float64

# %%
# place all of the data into a new school summary DataFrame and display
school_summary_df = pd.DataFrame({
                                "School Name": [school_name],
                                "School Type": [school_type],
                                "Total Students": [school_pop],
                                "Total School Budget": [school_budget],
                                "Per Student Budget": [student_budget.astype(float)],
                                "Average Math Score": [avg_math_school],
                                "Average Reading Score": [avg_read_school],
                                "% Passing Math": [pass_math_school],
                                "% Passing Reading": [pass_reading_school],
                                "% Overall Passing": [pass_overall_school]
                                })

school_summary_df.head(3)
# Out:
#                                          School Name  \
# 0  0         Huang High School
# 1         Huang Hi...
#
#                                          School Type  \
# 0  school_name
# Huang High School     District
# Hua...
#
#                                       Total Students  \
# 0  school_name
# Bailey High School       4976
# Cabr...
#
#                                  Total School Budget  \
# 0  school_name
# Huang High School     1910635
# Huan...
#
#                                   Per Student Budget  \
# 0  school_name
# Bailey High School    628.0
# Bailey...
#
#                                   Average Math Score  \
# 0  school_name
# Bailey High School       77.048432...
#
#                                Average Reading Score  \
# 0  school_name
# Bailey High School       81.033963...
#
#                                       % Passing Math  \
# 0  school_name
# Bailey High School       66.680064...
#
#                                    % Passing Reading  \
# 0  school_name
# Bailey High School       81.933280...
#
#                                    % Overall Passing
# 0  school_name
# Bailey High School       54.642283...

# %%
# set order
school_summary_df = school_summary_df [[
                                    'School Type', 
                                    'Total Students', 
                                    'Total School Budget', 
                                    'Per Student Budget', 
                                    'Average Math Score', 
                                    'Average Reading Score',
                                    '% Passing Math',
                                    '% Passing Reading',
                                    '% Overall Passing'
                                    ]]

school_summary_df.head(3)
# Out:
#                                          School Type  \
# 0  school_name
# Huang High School     District
# Hua...
#
#                                       Total Students  \
# 0  school_name
# Bailey High School       4976
# Cabr...
#
#                                  Total School Budget  \
# 0  school_name
# Huang High School     1910635
# Huan...
#
#                                   Per Student Budget  \
# 0  school_name
# Bailey High School    628.0
# Bailey...
#
#                                   Average Math Score  \
# 0  school_name
# Bailey High School       77.048432...
#
#                                Average Reading Score  \
# 0  school_name
# Bailey High School       81.033963...
#
#                                       % Passing Math  \
# 0  school_name
# Bailey High School       66.680064...
#
#                                    % Passing Reading  \
# 0  school_name
# Bailey High School       81.933280...
#
#                                    % Overall Passing
# 0  school_name
# Bailey High School       54.642283...

# %%
# use Groupby to display df by school
#school_summary_df.groupby(['School Name'])
#school_summary_df.set_index('school_name').groupby(['school_name'])

# %%
# format the data to match example
school_summary_df['Total Budget'] = school_summary_df['Total Budget'].map("${:,.2f}".format)
school_summary_df['Per Student Budget'] = school_summary_df['Per Student Budget'].map("${:,.2f}".format)

school_summary_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Budget'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-9fdd8c78b818> in <module>
#       1 # format the data to match example
# ----> 2 school_summary_df['Total Budget'] = school_summary_df['Total Budget'].map("${:,.2f}".format)
#       3 school_summary_df['Per Student Budget'] = school_summary_df['Per Student Budget'].map("${:,.2f}".format)
#       4
#       5 school_summary_df
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Budget'

# %%
# format the data in the table to read better
school_summary_df['Total Students'] = school_summary_df['Total Students'].map("{:,.0f}".format)
school_summary_df['Average Math Score'] = school_summary_df['Average Math Score'].map("{:,.2f}".format)
school_summary_df['Average Reading Score'] = school_summary_df['Average Reading Score'].map("{:,.2f}".format)
school_summary_df['% Passing Math'] = school_summary_df['% Passing Math'].map("{:.2f}".format)
school_summary_df['% Passing Reading'] = school_summary_df['% Passing Reading'].map("{:.2f}".format)
school_summary_df['% Overall Passing'] = school_summary_df['% Overall Passing'].map("{:.2f}".format)

school_summary_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-cbdc9bcbe7a0> in <module>
#       1 # format the data in the table to read better
# ----> 2 school_summary_df['Total Students'] = school_summary_df['Total Students'].map("{:,.0f}".format)
#       3 school_summary_df['Average Math Score'] = school_summary_df['Average Math Score'].map("{:,.2f}".format)
#       4 school_summary_df['Average Reading Score'] = school_summary_df['Average Reading Score'].map("{:,.2f}".format)
#       5 school_summary_df['% Passing Math'] = school_summary_df['% Passing Math'].map("{:.2f}".format)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: unsupported format string passed to Series.__format__

# %%
# display summary table
#school_summary_df.groupby(['School Name'])

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# show top five overall performing schools
top_five = school_summary_df.sort_values('% Overall Passing', ascending=False)

top_five.head(5)
# Out:
#                                          School Type  \
# 0  school_name
# Huang High School     District
# Hua...
#
#                                       Total Students  \
# 0  school_name
# Bailey High School       4976
# Cabr...
#
#                                  Total School Budget  \
# 0  school_name
# Huang High School     1910635
# Huan...
#
#                                   Per Student Budget  \
# 0  school_name
# Bailey High School    628.0
# Bailey...
#
#                                   Average Math Score  \
# 0  school_name
# Bailey High School       77.048432...
#
#                                Average Reading Score  \
# 0  school_name
# Bailey High School       81.033963...
#
#                                       % Passing Math  \
# 0  school_name
# Bailey High School       66.680064...
#
#                                    % Passing Reading  \
# 0  school_name
# Bailey High School       81.933280...
#
#                                    % Overall Passing
# 0  school_name
# Bailey High School       54.642283...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# show bottom five overall performing schools
bot_five = school_summary_df.sort_values(by='% Overall Passing')

bot_five.tail(5)
# Out:
#                                          School Type  \
# 0  school_name
# Huang High School     District
# Hua...
#
#                                       Total Students  \
# 0  school_name
# Bailey High School       4976
# Cabr...
#
#                                  Total School Budget  \
# 0  school_name
# Huang High School     1910635
# Huan...
#
#                                   Per Student Budget  \
# 0  school_name
# Bailey High School    628.0
# Bailey...
#
#                                   Average Math Score  \
# 0  school_name
# Bailey High School       77.048432...
#
#                                Average Reading Score  \
# 0  school_name
# Bailey High School       81.033963...
#
#                                       % Passing Math  \
# 0  school_name
# Bailey High School       66.680064...
#
#                                    % Passing Reading  \
# 0  school_name
# Bailey High School       81.933280...
#
#                                    % Overall Passing
# 0  school_name
# Bailey High School       54.642283...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# check existing grades
df['grade'].unique()
# Out:
# array(['9th', '12th', '11th', '10th'], dtype=object)

# %%
# create a series for each grade average math scores
math_9th = df.loc[df["grade"] == '9th'].groupby('school_name')['math_score'].mean()
math_10th = df.loc[df["grade"] == '10th'].groupby('school_name')['math_score'].mean()
math_11th = df.loc[df["grade"] == '11th'].groupby('school_name')['math_score'].mean()
math_12th = df.loc[df["grade"] == '12th'].groupby('school_name')['math_score'].mean()

# %%
# create dataframe to hold scores by grade
math_by_grade = pd.DataFrame({'9th': math_9th,
                            '10th': math_10th,
                            '11th': math_11th,
                            '12th': math_12th
                            })

# %%
# fix array order
math_by_grade = math_by_grade[['9th', '10th', '11th', '12th']]

math_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %%
# clean up format and display results
math_by_grade.style.format({'9th': '{:.1f}', 
                            "10th": '{:.1f}', 
                            "11th": "{:.1f}", 
                            "12th": "{:.1f}"
                            })
# Out:
# <style  type="text/css" >
# </style><table id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >9th</th>        <th class="col_heading level0 col1" >10th</th>        <th class="col_heading level0 col2" >11th</th>        <th class="col_heading level0 col3" >12th</th>    </tr>    <tr>        <th class="index_name level0" >school_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row0_col0" class="data row0 col0" >77.1</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row0_col1" class="data row0 col1" >77.0</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row0_col2" class="data row0 col2" >77.5</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row0_col3" class="data row0 col3" >76.5</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row1_col0" class="data row1 col0" >83.1</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row1_col1" class="data row1 col1" >83.2</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row1_col2" class="data row1 col2" >82.8</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row1_col3" class="data row1 col3" >83.3</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row2_col0" class="data row2 col0" >76.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row2_col1" class="data row2 col1" >76.5</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row2_col2" class="data row2 col2" >76.9</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row2_col3" class="data row2 col3" >77.2</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row3_col0" class="data row3 col0" >77.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row3_col1" class="data row3 col1" >77.7</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row3_col2" class="data row3 col2" >76.9</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row3_col3" class="data row3 col3" >76.2</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row4_col0" class="data row4 col0" >82.0</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row4_col1" class="data row4 col1" >84.2</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row4_col2" class="data row4 col2" >83.8</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row4_col3" class="data row4 col3" >83.4</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row5_col0" class="data row5 col0" >77.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row5_col1" class="data row5 col1" >77.3</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row5_col2" class="data row5 col2" >77.1</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row5_col3" class="data row5 col3" >77.2</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row6" class="row_heading level0 row6" >Holden High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row6_col0" class="data row6 col0" >83.8</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row6_col1" class="data row6 col1" >83.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row6_col2" class="data row6 col2" >85.0</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row6_col3" class="data row6 col3" >82.9</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row7" class="row_heading level0 row7" >Huang High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row7_col0" class="data row7 col0" >77.0</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row7_col1" class="data row7 col1" >75.9</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row7_col2" class="data row7 col2" >76.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row7_col3" class="data row7 col3" >77.2</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row8" class="row_heading level0 row8" >Johnson High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row8_col0" class="data row8 col0" >77.2</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row8_col1" class="data row8 col1" >76.7</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row8_col2" class="data row8 col2" >77.5</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row8_col3" class="data row8 col3" >76.9</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row9" class="row_heading level0 row9" >Pena High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row9_col0" class="data row9 col0" >83.6</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row9_col1" class="data row9 col1" >83.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row9_col2" class="data row9 col2" >84.3</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row9_col3" class="data row9 col3" >84.1</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row10_col0" class="data row10 col0" >76.9</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row10_col1" class="data row10 col1" >76.6</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row10_col2" class="data row10 col2" >76.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row10_col3" class="data row10 col3" >77.7</td>
#             </tr>
#             <tr>
#                         <th id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595level0_row11" class="row_heading level0 row11" >Shelton High School</th>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row11_col0" class="data row11 col0" >83.4</td>
#                         <td id="T_88ab97e2_c640_11ea_a0b6_0c8bfd5ff595row11_col1" class="data row11 col1" >82.9</td>

# %% [raw]
# # Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# create a series for each grade average math scores
reading_9th = df.loc[df["grade"] == '9th'].groupby('school_name')['reading_score'].mean()
reading_10th = df.loc[df["grade"] == '10th'].groupby('school_name')['reading_score'].mean()
reading_11th = df.loc[df["grade"] == '11th'].groupby('school_name')['reading_score'].mean()
reading_12th = df.loc[df["grade"] == '12th'].groupby('school_name')['reading_score'].mean()

# %%
# create dataframe to hold scores by grade
reading_by_grade = pd.DataFrame({'9th': reading_9th,
                            '10th': reading_10th,
                            '11th': reading_11th,
                            '12th': reading_12th
                            })

# %%
# fix array order
reading_by_grade = reading_by_grade[['9th', '10th', '11th', '12th']]

reading_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %%
# clean up format and display results
reading_by_grade.style.format({'9th': '{:.1f}', 
                            "10th": '{:.1f}', 
                            "11th": "{:.1f}", 
                            "12th": "{:.1f}"
                            })
# Out:
# <style  type="text/css" >
# </style><table id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >9th</th>        <th class="col_heading level0 col1" >10th</th>        <th class="col_heading level0 col2" >11th</th>        <th class="col_heading level0 col3" >12th</th>    </tr>    <tr>        <th class="index_name level0" >school_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row0_col0" class="data row0 col0" >81.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row0_col1" class="data row0 col1" >80.9</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row0_col2" class="data row0 col2" >80.9</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row0_col3" class="data row0 col3" >80.9</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row1_col0" class="data row1 col0" >83.7</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row1_col1" class="data row1 col1" >84.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row1_col2" class="data row1 col2" >83.8</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row1_col3" class="data row1 col3" >84.3</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row2_col0" class="data row2 col0" >81.2</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row2_col1" class="data row2 col1" >81.4</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row2_col2" class="data row2 col2" >80.6</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row2_col3" class="data row2 col3" >81.4</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row3_col0" class="data row3 col0" >80.6</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row3_col1" class="data row3 col1" >81.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row3_col2" class="data row3 col2" >80.4</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row3_col3" class="data row3 col3" >80.7</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row4_col0" class="data row4 col0" >83.4</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row4_col1" class="data row4 col1" >83.7</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row4_col2" class="data row4 col2" >84.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row4_col3" class="data row4 col3" >84.0</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row5_col0" class="data row5 col0" >80.9</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row5_col1" class="data row5 col1" >80.7</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row5_col2" class="data row5 col2" >81.4</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row5_col3" class="data row5 col3" >80.9</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row6" class="row_heading level0 row6" >Holden High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row6_col0" class="data row6 col0" >83.7</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row6_col1" class="data row6 col1" >83.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row6_col2" class="data row6 col2" >83.8</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row6_col3" class="data row6 col3" >84.7</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row7" class="row_heading level0 row7" >Huang High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row7_col0" class="data row7 col0" >81.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row7_col1" class="data row7 col1" >81.5</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row7_col2" class="data row7 col2" >81.4</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row7_col3" class="data row7 col3" >80.3</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row8" class="row_heading level0 row8" >Johnson High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row8_col0" class="data row8 col0" >81.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row8_col1" class="data row8 col1" >80.8</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row8_col2" class="data row8 col2" >80.6</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row8_col3" class="data row8 col3" >81.2</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row9" class="row_heading level0 row9" >Pena High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row9_col0" class="data row9 col0" >83.8</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row9_col1" class="data row9 col1" >83.6</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row9_col2" class="data row9 col2" >84.3</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row9_col3" class="data row9 col3" >84.6</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row10" class="row_heading level0 row10" >Rodriguez High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row10_col0" class="data row10 col0" >81.0</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row10_col1" class="data row10 col1" >80.6</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row10_col2" class="data row10 col2" >80.9</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row10_col3" class="data row10 col3" >80.4</td>
#             </tr>
#             <tr>
#                         <th id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595level0_row11" class="row_heading level0 row11" >Shelton High School</th>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row11_col0" class="data row11 col0" >84.1</td>
#                         <td id="T_c4434bcc_c640_11ea_8612_0c8bfd5ff595row11_col1" class="data row11 col1" >83.4</td>

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# create bins in which Data will be held
# bins are 0, 585.0, 630.0, 645.0, 675.0  
bins = [0, 585.0, 630.0, 645.0, 675.0]

# names of bins
group_names = ["<= $584", "$585 to $629", "$630 to $644", "$645 to $675"]

# %%
# process data into bins
pd.cut(school_summary_df['Per Student Budget'], bins, labels=group_names).head()

school_summary_df['Total School Budget'] = pd.cut(school_summary_df["Per Student Budget"], bins, labels=group_names, include_lowest=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-1cae853e2791> in <module>
#       1 # process data into bins
# ----> 2 pd.cut(school_summary_df['Per Student Budget'], bins, labels=group_names).head()
#       3
#       4 school_summary_df['Total School Budget'] = pd.cut(school_summary_df["Per Student Budget"], bins, labels=group_names, include_lowest=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# --> 388     ids = ensure_int64(bins.searchsorted(x, side=side))
#     389
#     390     if include_lowest:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# create GroupBy object
budget_group = school_summary_df.groupby('Total School Budget')

# %%
# calculate averages of the GroupBy object and display 
budget_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-55-2f963caba22a> in <module>
#       1 # calculate averages of the GroupBy object and display
# ----> 2 budget_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1224         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1225         return self._cython_agg_general(
# -> 1226             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1227         )
#    1228
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     992     ) -> DataFrame:
#     993         agg_blocks, agg_items = self._cython_agg_blocks(
# --> 994             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     995         )
#     996         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1093
#    1094         if not (agg_blocks or split_frames):
# -> 1095             raise DataError("No numeric types to aggregate")
#    1096
#    1097         if split_items:
#
# DataError: No numeric types to aggregate

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# create bins in which Data will be held
# bins are 0,999, 1999, 5000  
bins = [0, 999, 1999, 5000]

# names of bins
group_names = ["Small (<1000)", "Medium (1000-1999)", "Large (2000-5000)"]

# %%
# process data into bins
pd.cut(school_summary_df['Total Students'], bins, labels=group_names).head()

school_summary_df['Total Students'] = pd.cut(school_summary_df["Per Student Budget"], bins, labels=group_names, include_lowest=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-e395f9a3729a> in <module>
#       1 # process data into bins
# ----> 2 pd.cut(school_summary_df['Total Students'], bins, labels=group_names).head()
#       3
#       4 school_summary_df['Total Students'] = pd.cut(school_summary_df["Per Student Budget"], bins, labels=group_names, include_lowest=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# --> 388     ids = ensure_int64(bins.searchsorted(x, side=side))
#     389
#     390     if include_lowest:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# create GroupBy object
size_group = school_summary_df.groupby('Total Students')

# %%
# calculate averages of the GroupBy object and display 
size_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-59-31e6916a919e> in <module>
#       1 # calculate averages of the GroupBy object and display
# ----> 2 size_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1224         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1225         return self._cython_agg_general(
# -> 1226             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1227         )
#    1228
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     992     ) -> DataFrame:
#     993         agg_blocks, agg_items = self._cython_agg_blocks(
# --> 994             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     995         )
#     996         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1093
#    1094         if not (agg_blocks or split_frames):
# -> 1095             raise DataError("No numeric types to aggregate")
#    1096
#    1097         if split_items:
#
# DataError: No numeric types to aggregate

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# create GroupBy object
type_group = school_summary_df.groupby('type')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-d89e1761f176> in <module>
#       1 # create GroupBy object
# ----> 2 type_group = school_summary_df.groupby('type')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     598                 in_axis, name, level, gpr = False, None, gpr, None
#     599             else:
# --> 600                 raise KeyError(gpr)
#     601         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     602             # Add key to exclusions
#
# KeyError: 'type'

# %%
# calculate averages of the GroupBy object and display 
type_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-a0c2e98a7cd9> in <module>
#       1 # calculate averages of the GroupBy object and display
# ----> 2 type_group[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]].mean()
#
# NameError: name 'type_group' is not defined
